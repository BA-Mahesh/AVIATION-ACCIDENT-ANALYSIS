# %% [markdown]
# # AVIATION ACCIDENT ANALYSIS
# ---------------------------------------------------
# This project is meant to explore, analyse and visualize aviation accidents and related factors such as reasons, survival rates, fatalities, locations etc.
#
# Detailed analyses of following factors:
#
#       -The planes crashed per year.
#
#       -People aboard per year during crashes.
#
#       -People dead per year during crashes.
#
#       -People survived per year during crashes.

# %%
import pandas as pd #data processing and I/O operations
import numpy as np #linear algebra
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import date, datetime, timedelta #pip install datatime

# %%
data = pd.read_csv('D:/datasets/Dataset1.csv')

# %%
data
# Out:
#             Date   Time                                           Location  \
# 0     09/17/1908  17:18                                Fort Myer, Virginia
# 1     07/12/1912  06:30                            AtlantiCity, New Jersey
# 2     08/06/1913    NaN                 Victoria, British Columbia, Canada
# 3     09/09/1913  18:30                                 Over the North Sea
# 4     10/17/1913  10:30                         Near Johannisthal, Germany
# ...          ...    ...                                                ...
# 5263  05/20/2009  06:30                             Near Madiun, Indonesia
# 5264  05/26/2009    NaN                  Near Isiro, DemocratiRepubliCongo
# 5265  06/01/2009  00:15  AtlantiOcean, 570 miles northeast of Natal, Br...
# 5266  06/07/2009  08:30       Near Port Hope Simpson, Newfoundland, Canada
# 5267  06/08/2009    NaN                  State of Arunachal Pradesh, India
#
#                              Operator Flight #  \
# 0                Military - U.S. Army      NaN
# 1                Military - U.S. Navy      NaN
# 2                             Private        -
# 3              Military - German Navy      NaN
# 4              Military - German Navy      NaN
# ...                               ...      ...
# 5263  Military - Indonesian Air Force      NaN
# 5264                      Service Air      NaN
# 5265                       Air France      447
# 5266                       Strait Air      NaN
# 5267      Military - Indian Air Force      NaN
#
#                                           Route  \
# 0                                 Demonstration
# 1                                   Test flight
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ...                                         ...
# 5263                           Jakarta - Maduin
# 5264                               Goma - Isiro
# 5265                     Rio de Janeiro - Paris
# 5266  Lourdes de BlanSablon - Port Hope Simpson
# 5267                         Mechuka for Jorhat
#
#                                   Type Registration cn/In  Aboard  Fatalities  \
# 0                     Wright Flyer III          NaN     1     2.0         1.0
# 1                            Dirigible          NaN   NaN     5.0         5.0
# 2                     Curtiss seaplane          NaN   NaN     1.0         1.0
# 3               Zeppelin L-1 (airship)          NaN   NaN    20.0        14.0
# 4               Zeppelin L-2 (airship)          NaN   NaN    30.0        30.0
# ...                                ...          ...   ...     ...         ...
# 5263           Lockheed C-130 Hercules       A-1325  1982   112.0        98.0
# 5264                     Antonov An-26       9Q-CSA  5005     4.0         4.0
# 5265                   Airbus A330-203       F-GZCP   660   228.0       228.0
# 5266  Britten-Norman BN-2A-27 Islander      C-FJJR    424     1.0         1.0
# 5267                     Antonov An-32          NaN   NaN    13.0        13.0
#
#       Ground                                            Summary
# 0        0.0  During a demonstration flight, a U.S. Army fly...
# 1        0.0  First U.S. dirigible Akron exploded just offsh...
# 2        0.0  The first fatal airplane accident in Canada oc...
# 3        0.0  The airship flew into a thunderstorm and encou...
# 4        0.0  Hydrogen gas which was being vented was sucked...
# ...      ...                                                ...
# 5263     2.0  While on approach, the military transport cras...
# 5264     NaN  The cargo plane crashed while on approach to I...
# 5265     0.0  The Airbus went missing over the AtlantiOcean ...
# 5266     0.0  The air ambulance crashed into hills while att...
# 5267     0.0  The military transport went missing while en r...
#
# [5268 rows x 13 columns]

# %%
data.shape
# Out:
# (5268, 13)

# %% [markdown]
# ### Data Set has 5268 Rows and 12 Columns

# %%
data.head(10)
# Out:
#          Date   Time                            Location  \
# 0  09/17/1908  17:18                 Fort Myer, Virginia
# 1  07/12/1912  06:30             AtlantiCity, New Jersey
# 2  08/06/1913    NaN  Victoria, British Columbia, Canada
# 3  09/09/1913  18:30                  Over the North Sea
# 4  10/17/1913  10:30          Near Johannisthal, Germany
# 5  03/05/1915  01:00                     Tienen, Belgium
# 6  09/03/1915  15:20               Off Cuxhaven, Germany
# 7  07/28/1916    NaN               Near Jambol, Bulgeria
# 8  09/24/1916  01:00                 Billericay, England
# 9  10/01/1916  23:45                Potters Bar, England
#
#                  Operator Flight #          Route  \
# 0    Military - U.S. Army      NaN  Demonstration
# 1    Military - U.S. Navy      NaN    Test flight
# 2                 Private        -            NaN
# 3  Military - German Navy      NaN            NaN
# 4  Military - German Navy      NaN            NaN
# 5  Military - German Navy      NaN            NaN
# 6  Military - German Navy      NaN            NaN
# 7  Military - German Army      NaN            NaN
# 8  Military - German Navy      NaN            NaN
# 9  Military - German Navy      NaN            NaN
#
#                             Type Registration cn/In  Aboard  Fatalities  \
# 0               Wright Flyer III          NaN     1     2.0         1.0
# 1                      Dirigible          NaN   NaN     5.0         5.0
# 2               Curtiss seaplane          NaN   NaN     1.0         1.0
# 3         Zeppelin L-1 (airship)          NaN   NaN    20.0        14.0
# 4         Zeppelin L-2 (airship)          NaN   NaN    30.0        30.0
# 5         Zeppelin L-8 (airship)          NaN   NaN    41.0        21.0
# 6        Zeppelin L-10 (airship)          NaN   NaN    19.0        19.0
# 7  Schutte-Lanz S-L-10 (airship)          NaN   NaN    20.0        20.0
# 8        Zeppelin L-32 (airship)          NaN   NaN    22.0        22.0
# 9        Zeppelin L-31 (airship)          NaN   NaN    19.0        19.0
#
#    Ground                                            Summary
# 0     0.0  During a demonstration flight, a U.S. Army fly...
# 1     0.0  First U.S. dirigible Akron exploded just offsh...
# 2     0.0  The first fatal airplane accident in Canada oc...
# 3     0.0  The airship flew into a thunderstorm and encou...
# 4     0.0  Hydrogen gas which was being vented was sucked...
# 5     0.0  Crashed into trees while attempting to land af...
# 6     0.0  Exploded and burned near Neuwerk Island,  when...
# 7     0.0         Crashed near the Black Sea, cause unknown.
# 8     0.0  Shot down by British aircraft crashing in flames.
# 9     0.0  Shot down in flames by the British 39th Home D...

# %%
data.tail(5)
# Out:
#             Date   Time                                           Location  \
# 5263  05/20/2009  06:30                             Near Madiun, Indonesia
# 5264  05/26/2009    NaN                  Near Isiro, DemocratiRepubliCongo
# 5265  06/01/2009  00:15  AtlantiOcean, 570 miles northeast of Natal, Br...
# 5266  06/07/2009  08:30       Near Port Hope Simpson, Newfoundland, Canada
# 5267  06/08/2009    NaN                  State of Arunachal Pradesh, India
#
#                              Operator Flight #  \
# 5263  Military - Indonesian Air Force      NaN
# 5264                      Service Air      NaN
# 5265                       Air France      447
# 5266                       Strait Air      NaN
# 5267      Military - Indian Air Force      NaN
#
#                                           Route  \
# 5263                           Jakarta - Maduin
# 5264                               Goma - Isiro
# 5265                     Rio de Janeiro - Paris
# 5266  Lourdes de BlanSablon - Port Hope Simpson
# 5267                         Mechuka for Jorhat
#
#                                   Type Registration cn/In  Aboard  Fatalities  \
# 5263           Lockheed C-130 Hercules       A-1325  1982   112.0        98.0
# 5264                     Antonov An-26       9Q-CSA  5005     4.0         4.0
# 5265                   Airbus A330-203       F-GZCP   660   228.0       228.0
# 5266  Britten-Norman BN-2A-27 Islander      C-FJJR    424     1.0         1.0
# 5267                     Antonov An-32          NaN   NaN    13.0        13.0
#
#       Ground                                            Summary
# 5263     2.0  While on approach, the military transport cras...
# 5264     NaN  The cargo plane crashed while on approach to I...
# 5265     0.0  The Airbus went missing over the AtlantiOcean ...
# 5266     0.0  The air ambulance crashed into hills while att...
# 5267     0.0  The military transport went missing while en r...

# %% [markdown]
# #### By observing above two lines of codes it is clear that the data set has NaN values
#
# #### In operators  - Their is a mix of Cases(like Upper case and Lower case)

# %%
## Now Let us Check for missing values

data.isnull().sum()
# Out:
# Date               0
# Time            2219
# Location          20
# Operator          18
# Flight #        4199
# Route           1706
# Type              27
# Registration     335
# cn/In           1228
# Aboard            22
# Fatalities        12
# Ground            22
# Summary          390
# dtype: int64

# %%
data['Time'] = data['Time'].replace(np.nan, '00:00')

# %% [markdown]
# #### We are replacing time value by Zero and assume that incidents happend exactly at 00:00 Hrs

# %%
data.isnull().sum()
# Out:
# Date               0
# Time               0
# Location          20
# Operator          18
# Flight #        4199
# Route           1706
# Type              27
# Registration     335
# cn/In           1228
# Aboard            22
# Fatalities        12
# Ground            22
# Summary          390
# dtype: int64

# %%
data['Time'].value_counts()
# Out:
# 00:00    2223
# 15:00      32
# 12:00      31
# 11:00      29
# 16:00      26
#          ...
# 15:02       1
# 10:14       1
# 22:51       1
# 05:14       1
# 10:47       1
# Name: Time, Length: 1005, dtype: int64

# %%
data['Time'] = data['Time'].str.replace('c: ','')
data['Time'] = data['Time'].str.replace('c:','')
data['Time'] = data['Time'].str.replace('c','')
data['Time'] = data['Time'].str.replace('12\'20','12:20')
data['Time'] = data['Time'].str.replace('18.40','18:40')
data['Time'] = data['Time'].str.replace('0943','09:43')
data['Time'] = data['Time'].str.replace('22\'08','22:08')
data['Time'] = data['Time'].str.replace('114:20','00:00')

# %%
data['Time'] = data['Date'] + ' ' +data['Time']

def todate(x):
    return datetime.strptime(x, '%m/%d/%Y %H:%M')

data['Time'] = data['Time'].apply(todate)

# %% [markdown]
# ### We are displaying the in the format Month / Day / Year / Hour / Minutes

# %%
print('Data ranges from ' + str(data.Time.min()) + ' to ' + str(data.Time.max()))
# Out:
# Data ranges from 1908-09-17 17:18:00 to 2009-06-08 00:00:00

# %% [markdown]
# #### by above we get the ranges of Data - min to max

# %%
data.Operator = data.Operator.str.upper()

# %%
data.head()
# Out:
#          Date                Time                            Location  \
# 0  09/17/1908 1908-09-17 17:18:00                 Fort Myer, Virginia
# 1  07/12/1912 1912-07-12 06:30:00             AtlantiCity, New Jersey
# 2  08/06/1913 1913-08-06 00:00:00  Victoria, British Columbia, Canada
# 3  09/09/1913 1913-09-09 18:30:00                  Over the North Sea
# 4  10/17/1913 1913-10-17 10:30:00          Near Johannisthal, Germany
#
#                  Operator Flight #          Route                    Type  \
# 0    MILITARY - U.S. ARMY      NaN  Demonstration        Wright Flyer III
# 1    MILITARY - U.S. NAVY      NaN    Test flight               Dirigible
# 2                 PRIVATE        -            NaN        Curtiss seaplane
# 3  MILITARY - GERMAN NAVY      NaN            NaN  Zeppelin L-1 (airship)
# 4  MILITARY - GERMAN NAVY      NaN            NaN  Zeppelin L-2 (airship)
#
#   Registration cn/In  Aboard  Fatalities  Ground  \
# 0          NaN     1     2.0         1.0     0.0
# 1          NaN   NaN     5.0         5.0     0.0
# 2          NaN   NaN     1.0         1.0     0.0
# 3          NaN   NaN    20.0        14.0     0.0
# 4          NaN   NaN    30.0        30.0     0.0
#
#                                              Summary
# 0  During a demonstration flight, a U.S. Army fly...
# 1  First U.S. dirigible Akron exploded just offsh...
# 2  The first fatal airplane accident in Canada oc...
# 3  The airship flew into a thunderstorm and encou...
# 4  Hydrogen gas which was being vented was sucked...

# %% [markdown]
# ### We have converted the data in operator to upper case to make it uniform

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# #### Let us Analyse First how many accidents happend in 1 year

# %%
Temp = data.groupby(data.Time.dt.year)[['Date']].count()
Temp.head()
# Out:
#       Date
# Time
# 1908     1
# 1912     1
# 1913     3
# 1915     2
# 1916     5

# %%
Temp = Temp.rename(columns={'Date':'Count'})

# %%
Temp.head(1)
# Out:
#       Count
# Time
# 1908      1

# %%
plt.figure(figsize=(12,6))
plt.style.use('bmh')
plt.plot(Temp.index, 'Count', data=Temp, color='Purple', marker='.', linewidth=1)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.title('Count of accidents by year', fontsize=15)
plt.show()

# %% [markdown]
#  #### Visualization of Accidents  - Year by Year

# %%
import matplotlib.pylab as pl
import matplotlib.gridspec as gridspec


gs = gridspec.GridSpec(2,2)
pl.figure(figsize=(15,10))
plt.style.use('seaborn-muted')
ax = pl.subplot(gs[0,:])
sns.barplot(data.groupby(data.Time.dt.month)[['Date']].count().index, 'Date',
            data = data.groupby(data.Time.dt.month)[['Date']].count(), color='Purple', linewidth=1)
plt.xticks(data.groupby(data.Time.dt.month)[['Date']].count().index, 
           ['Jan', 'Feb', 'March', 'April', 'May', 'June', 'July', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.xlabel('Month', fontsize=11)
plt.ylabel('Count', fontsize=11)
plt.title('Count of accidents by month', fontsize=14)

ax = pl.subplot(gs[1,0])
sns.barplot(data.groupby(data.Time.dt.weekday)[['Date']].count().index, 'Date',
            data = data.groupby(data.Time.dt.weekday)[['Date']].count(), color='Violet', linewidth=2)
plt.xticks(data.groupby(data.Time.dt.weekday)[['Date']].count().index, 
           ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun'])
plt.xlabel('Weekday', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.title('Count of accidents by Weekday', fontsize=14)

ax = pl.subplot(gs[1,1])
sns.barplot(data[data.Time.dt.hour != 0].groupby(data.Time.dt.hour )[['Date']].count().index, 'Date',
            data = data[data.Time.dt.hour != 0].groupby(data.Time.dt.hour)[['Date']].count(), color='lightblue', linewidth=2)
plt.xlabel('Hour', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.title('Count of accidents by Hour', fontsize=14)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Asus\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Asus\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Asus\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ### By seeing the Graphs we can say that
# #### - Most Accidents happend between 9 - 10 AM and in the evening 7- 8 PM
# #### - Most Acciednts Happend on Thursday's
# #### - Most Accidents Happend in the Month of Nov

# %% [markdown]
# ## Passenger Flights vs Military Flights

# %%
Temp = data.copy()
Temp['isMilitary'] = Temp.Operator.str.contains('MILITARY')
Temp = Temp.groupby('isMilitary')[['isMilitary']].count()
Temp.index = ['Passenger', 'Military']
Temp
# Out:
#            isMilitary
# Passenger        4469
# Military          781

# %%
Temp2 = data.copy()
Temp2['Military'] = Temp2.Operator.str.contains('MILITARY')
Temp2['Passenger'] = Temp2.Military == False
Temp2 = Temp2.loc[:,['Time', 'Military', 'Passenger']]
Temp2
# Out:
#                     Time Military  Passenger
# 0    1908-09-17 17:18:00     True      False
# 1    1912-07-12 06:30:00     True      False
# 2    1913-08-06 00:00:00    False       True
# 3    1913-09-09 18:30:00     True      False
# 4    1913-10-17 10:30:00     True      False
# ...                  ...      ...        ...
# 5263 2009-05-20 06:30:00     True      False
# 5264 2009-05-26 00:00:00    False       True
# 5265 2009-06-01 00:15:00    False       True
# 5266 2009-06-07 08:30:00    False       True
# 5267 2009-06-08 00:00:00     True      False
#
# [5268 rows x 3 columns]

# %%
Temp2 = Temp2.groupby(Temp2.Time.dt.year)[['Military', 'Passenger']].aggregate(np.count_nonzero)

# %%
Temp2
# Out:
#       Military  Passenger
# Time
# 1908         1          0
# 1912         1          0
# 1913         2          1
# 1915         2          0
# 1916         5          0
# ...        ...        ...
# 2005         7         44
# 2006        12         37
# 2007         6         48
# 2008         7         55
# 2009         4         20
#
# [98 rows x 2 columns]

# %% [markdown]
# ### Now we can see the Number of  Acciedents
# #### - Year Wise / By Military / By Passenger

# %%
colors = ['Green', 'Blue']
plt.figure(figsize=(15,6))
plt.subplot(1,2,1)
patches, texts = plt.pie(Temp.isMilitary, colors=colors, labels=Temp.isMilitary, startangle=90)
plt.legend(patches, Temp.index, fontsize=12)
plt.axis('equal')
plt.title('Total number of accidents by flight type', fontsize=15)

plt.subplot(1,2,2)
plt.plot(Temp2.index, 'Military', data=Temp2, color='Blue', marker='.', linewidth=1)
plt.plot(Temp2.index, 'Passenger', data=Temp2, color='Green', marker='.', linewidth=1)
plt.legend(fontsize=12)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.title('Count of accidents by flight type', fontsize=15)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### From the above we can Clearly See that
# #### - Passenger Aircrafts has involved maximum number of Accidents as that of Military Aircrafts
# #### - Passenger Aircrafts Accidents were at maximum during the period 1970 - 1980
# #### - Militart Aircraft Accidents were at Maximum between 1940 - 1950

# %% [markdown]
# ### Total Number of fatalities

# %%
Fatalities = data.groupby(data.Time.dt.year).sum()
Fatalities['Proportion'] = Fatalities['Fatalities'] / Fatalities['Aboard']

plt.figure(figsize=(15,6))
plt.subplot(1,2,1)
plt.fill_between(Fatalities.index, 'Aboard', data=Fatalities, color='Purple', alpha=0.2)
plt.plot(Fatalities.index, 'Aboard', data=Fatalities, marker='.', color='Blue', alpha=0.6, linewidth=1)

plt.fill_between(Fatalities.index, 'Fatalities', data=Fatalities, color='Green', alpha=0.2)
plt.plot(Fatalities.index, 'Fatalities', data=Fatalities, marker='.', color='Green', alpha=0.6, linewidth=1)

plt.legend(fontsize=12)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Number of People', fontsize=12)
plt.title('Total number of Fatalities by Year')



plt.subplot(1,2,2)
plt.plot(Fatalities.index, 'Proportion', data=Fatalities, marker='.', color='red', linewidth=2)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Fatalities ratio', fontsize=12)
plt.title('Fatalities ratio by year', fontsize=15)
plt.show()

# %% [markdown]
# ## We know for a Fact that the Passenger Aircraft has involed in Max Accidents
#
# ### - Let us Analyse the Fatalities per Year During Crash
# ### - Let us Analyse the Deaths per Year During Crash
# ### - Let us see which Fligh Operator has been involved in Maximum crashes

# %% [markdown]
# ### Dataset 2 import

# %%
Totals = pd.read_csv('D:/datasets/Dataset2.csv')
Totals
# Out:
#      Country Name Country Code                     Indicator Name  \
# 0           Aruba          ABW  Air transport, passengers carried
# 1     Afghanistan          AFG  Air transport, passengers carried
# 2          Angola          AGO  Air transport, passengers carried
# 3         Albania          ALB  Air transport, passengers carried
# 4         Andorra          AND  Air transport, passengers carried
# ..            ...          ...                                ...
# 259        Kosovo          XKX  Air transport, passengers carried
# 260   Yemen, Rep.          YEM  Air transport, passengers carried
# 261  South Africa          ZAF  Air transport, passengers carried
# 262        Zambia          ZMB  Air transport, passengers carried
# 263      Zimbabwe          ZWE  Air transport, passengers carried
#
#     Indicator Code  1960  1961  1962  1963  1964  1965  ...          2011  \
# 0      IS.AIR.PSGR   NaN   NaN   NaN   NaN   NaN   NaN  ...           NaN
# 1      IS.AIR.PSGR   NaN   NaN   NaN   NaN   NaN   NaN  ...  2.279341e+06
# 2      IS.AIR.PSGR   NaN   NaN   NaN   NaN   NaN   NaN  ...  9.877980e+05
# 3      IS.AIR.PSGR   NaN   NaN   NaN   NaN   NaN   NaN  ...  8.297789e+05
# 4      IS.AIR.PSGR   NaN   NaN   NaN   NaN   NaN   NaN  ...           NaN
# ..             ...   ...   ...   ...   ...   ...   ...  ...           ...
# 259    IS.AIR.PSGR   NaN   NaN   NaN   NaN   NaN   NaN  ...           NaN
# 260    IS.AIR.PSGR   NaN   NaN   NaN   NaN   NaN   NaN  ...  1.492073e+06
# 261    IS.AIR.PSGR   NaN   NaN   NaN   NaN   NaN   NaN  ...  1.640778e+07
# 262    IS.AIR.PSGR   NaN   NaN   NaN   NaN   NaN   NaN  ...  3.060343e+05
# 263    IS.AIR.PSGR   NaN   NaN   NaN   NaN   NaN   NaN  ...  2.793476e+05
#
#              2012        2013          2014        2015        2016  \
# 0             NaN         NaN           NaN         NaN         NaN
# 1    1.737962e+06   2044188.0  2.209428e+06   1929907.0   1917924.0
# 2    1.132424e+06   1321872.0  1.409952e+06   1244491.0   1482546.0
# 3    8.143397e+05    865848.0  1.516320e+05         NaN     26634.0
# 4             NaN         NaN           NaN         NaN         NaN
# ..            ...         ...           ...         ...         ...
# 259           NaN         NaN           NaN         NaN         NaN
# 260  1.299707e+06   1664220.0  1.665552e+06    443685.0    242723.0
# 261  1.757157e+07  16311250.0  1.702664e+07  18882898.0  19744932.0
# 262  1.272966e+05     10032.0  8.592000e+03    203617.0    144060.0
# 263  3.209460e+05    351564.0  3.012600e+05    370165.0    378803.0
#
#            2017          2018  2019  Unnamed: 64
# 0      223502.0  2.742800e+05   NaN          NaN
# 1     1647425.0  1.722613e+06   NaN          NaN
# 2     1375523.0  1.516628e+06   NaN          NaN
# 3      204090.0  3.031370e+05   NaN          NaN
# 4           NaN           NaN   NaN          NaN
# ..          ...           ...   ...          ...
# 259         NaN           NaN   NaN          NaN
# 260    132571.0  3.363100e+05   NaN          NaN
# 261  20821044.0  2.392175e+07   NaN          NaN
# 262    154573.0  8.904000e+03   NaN          NaN
# 263    282539.0  2.825390e+05   NaN          NaN
#
# [264 rows x 65 columns]

# %%
Totals.head()
# Out:
#   Country Name Country Code                     Indicator Name Indicator Code  \
# 0        Aruba          ABW  Air transport, passengers carried    IS.AIR.PSGR
# 1  Afghanistan          AFG  Air transport, passengers carried    IS.AIR.PSGR
# 2       Angola          AGO  Air transport, passengers carried    IS.AIR.PSGR
# 3      Albania          ALB  Air transport, passengers carried    IS.AIR.PSGR
# 4      Andorra          AND  Air transport, passengers carried    IS.AIR.PSGR
#
#    1960  1961  1962  1963  1964  1965  ...          2011          2012  \
# 0   NaN   NaN   NaN   NaN   NaN   NaN  ...           NaN           NaN
# 1   NaN   NaN   NaN   NaN   NaN   NaN  ...  2.279341e+06  1.737962e+06
# 2   NaN   NaN   NaN   NaN   NaN   NaN  ...  9.877980e+05  1.132424e+06
# 3   NaN   NaN   NaN   NaN   NaN   NaN  ...  8.297789e+05  8.143397e+05
# 4   NaN   NaN   NaN   NaN   NaN   NaN  ...           NaN           NaN
#
#         2013       2014       2015       2016       2017        2018  2019  \
# 0        NaN        NaN        NaN        NaN   223502.0   274280.00   NaN
# 1  2044188.0  2209428.0  1929907.0  1917924.0  1647425.0  1722612.61   NaN
# 2  1321872.0  1409952.0  1244491.0  1482546.0  1375523.0  1516628.00   NaN
# 3   865848.0   151632.0        NaN    26634.0   204090.0   303137.00   NaN
# 4        NaN        NaN        NaN        NaN        NaN         NaN   NaN
#
#    Unnamed: 64
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#
# [5 rows x 65 columns]

# %%
Totals = Totals.drop(['Country Name', 'Country Code', 'Indicator Code', 'Indicator Name'], axis=1)

# %% [markdown]
# #### We will be dropping the 'Country Name', 'Country Code', 'Indicator Code', 'Indicator Name as we will not be considering it for analysis

# %%
Totals = Totals.replace(np.nan, 0)

# %% [markdown]
# #### We will replace all Nan values by Zero

# %%
Totals = pd.DataFrame(Totals.sum())

# %%
Totals.tail()
# Out:
#                         0
# 2016         3.104586e+10
# 2017         3.350035e+10
# 2018         3.588238e+10
# 2019         0.000000e+00
# Unnamed: 64  0.000000e+00

# %%
Totals = Totals.drop(Totals.index[0:10])
Totals = Totals['1970':'2008']
Totals.columns = ['Sum']
Totals.index.name = 'Year'

# %% [markdown]
# #### We have Renamed the Column as Years and Row as Sum

# %%
Totals.head()
# Out:
#                Sum
# Year
# 1970  1.850484e+09
# 1971  1.979946e+09
# 1972  1.817426e+09
# 1973  2.388611e+09
# 1974  2.867234e+09

# %%
Fatalities = Fatalities.reset_index()

# %%
Fatalities.head()
# Out:
#    Time  Aboard  Fatalities  Ground  Proportion
# 0  1908     2.0         1.0     0.0    0.500000
# 1  1912     5.0         5.0     0.0    1.000000
# 2  1913    51.0        45.0     0.0    0.882353
# 3  1915    60.0        40.0     0.0    0.666667
# 4  1916   109.0       108.0     0.0    0.990826

# %%
Fatalities.Time = Fatalities.Time.apply(str)
Fatalities.index = Fatalities['Time']
del Fatalities['Time']
Fatalities = Fatalities['1970':'2008']
Fatalities = Fatalities[['Fatalities']]
Totals = pd.concat([Totals,Fatalities], axis=1)
Totals['Ratio'] = Totals['Fatalities'] / Totals['Sum'] * 100

# %%
Totals.head()
# Out:
#                Sum  Fatalities     Ratio
# 1970  1.850484e+09      2049.0  0.000111
# 1971  1.979946e+09      1932.0  0.000098
# 1972  1.817426e+09      2937.0  0.000162
# 1973  2.388611e+09      2485.0  0.000104
# 1974  2.867234e+09      2318.0  0.000081

# %% [markdown]
# ### Shows Total number of people Travelling, Fatalities and thier Ratio

# %%
gs = gridspec.GridSpec(2,2)
pl.figure(figsize=(15,10))

ax= pl.subplot(gs[0,0])
plt.plot(Totals.index, 'Sum', data=Totals, marker='.', color='Purple', linewidth=1)
plt.xlabel('Year')
plt.ylabel('Number of passengers')
plt.title('Total number of passengers by Year', fontsize=15)
plt.xticks(rotation=90)

x= pl.subplot(gs[0,1])
plt.plot(Fatalities.index, 'Fatalities', data=Totals, marker='.', color='red', linewidth=1)
plt.xlabel('Year')
plt.ylabel('Number of Deaths')
plt.title('Total number of Deaths by Year', fontsize=15)
plt.xticks(rotation=90)

x= pl.subplot(gs[1,:])
plt.plot(Totals.index, 'Ratio', data=Totals, marker='.', color='Blue', linewidth=1)
plt.xlabel('Year')
plt.ylabel('Ratio')
plt.title('Fatalities/Total number of passengers ratio by Year', fontsize=15)
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### By Seeing the Above Graphs We can Say that
#
# #### - Number of Passengers Travelling by Air has been increasing year by Year
# #### - Death rate was maximum during 1971,1985 and 1997
# #### - Fatalities / Total number of Passengers ratio is decreasing as the year is increasing (by use of Advance Technologies)

# %% [markdown]
# ### Operator Analysis

# %%
data.Operator = data.Operator.str.upper()
data.Operator = data.Operator.replace("A B AEROTRANSPORT", 'AB AEROTRANSPORT')

Total_by_Op = data.groupby('Operator')[['Operator']].count()
Total_by_Op = Total_by_Op.rename(columns={'Operator':'Count'})
Total_by_Op = Total_by_Op.sort_values(by='Count', ascending=False).head(15)

# %%
Total_by_Op
# Out:
#                                      Count
# Operator
# AEROFLOT                               179
# MILITARY - U.S. AIR FORCE              176
# AIR FRANCE                              70
# DEUTSCHE LUFTHANSA                      65
# AIR TAXI                                48
# UNITED AIR LINES                        44
# CHINA NATIONAL AVIATION CORPORATION     44
# MILITARY - U.S. ARMY AIR FORCES         43
# PAN AMERICAN WORLD AIRWAYS              41
# AMERICAN AIRLINES                       36
# MILITARY - U.S. NAVY                    36
# MILITARY - ROYAL AIR FORCE              36
# US AERIAL MAIL SERVICE                  36
# INDIAN AIRLINES                         34
# KLM ROYAL DUTCH AIRLINES                33

# %% [markdown]
# #### We have Totally 15 Operators in this data set

# %%
plt.figure(figsize=(12,6))
sns.barplot(y=Total_by_Op.index, x='Count', data=Total_by_Op, palette='gist_heat', orient='h')
plt.xlabel('Count', fontsize=12)
plt.ylabel('Operator', fontsize=12)
plt.title("Total Count of the Operator", fontsize=15)
plt.show()

# %% [markdown]
# #### Graphical Representation of flights

# %%
Prop_by_Op = data.groupby('Operator')[['Fatalities']].sum()
Prop_by_Op = Prop_by_Op.rename(columns={'Operator':'Fatalities'})
Prop_by_Op = Prop_by_Op.sort_values(by='Fatalities', ascending=False)
Prop_by_OpTop = Prop_by_Op.head(15)

# %%
plt.figure(figsize=(12,6))
sns.barplot(y=Prop_by_OpTop.index, x='Fatalities', data=Prop_by_OpTop, palette='gist_heat', orient='h')
plt.xlabel('Fatalities', fontsize=12)
plt.ylabel('Operator', fontsize=12)
plt.title("Total Fatalities of the Operator", fontsize=15)
plt.show()

# %% [markdown]
# #### Aeroflot operator has maximum Fatalities

# %% [markdown]
# #### Let us Find the operators which has minimum Fatalities

# %%
Prop_by_Op[Prop_by_Op['Fatalities'] == Prop_by_Op.Fatalities.min()].index.tolist()
# Out:
# ['MILITARY - EJÉRCITO DEL AIRE',
#  'ARARAT AVIA',
#  'HEWA BORA AIRWAYS',
#  'MILITARY - UKRAINE AIR FORCE',
#  'MILITARY - U.S. AIR FORCE / MILITARY U.S. AIR FORCE',
#  'CANADIAN AIR TRANSAT',
#  'MILITARY U.S. NAVY',
#  'ISLAND SKY FERRY - AIR TAXI',
#  'US AIRWAYS',
#  'SOUTHWEST AIRLINES',
#  'CENTURIAN AIR CARGO',
#  'AMERICAN INTERNATIONAL AIRWAYS',
#  'REGIONAL COMPAGNIE AERIENNE EUROPEENNE',
#  'WESTERN HELICOPTER']

# %%
Aeroflot = data[data.Operator == 'AEROFLOT']
Count_by_year = Aeroflot.groupby(data.Time.dt.year)[['Date']].count()
Count_by_year = Count_by_year.rename(columns={'Date':'Count'})

plt.figure(figsize=(12,6))
plt.plot(Count_by_year.index, 'Count', data=Count_by_year, marker='.', color='red', linewidth=1)
plt.xlabel('Year', fontsize=11)
plt.ylabel('Count', fontsize=11)
plt.title('Count of accidents by year (Aeroflot)', fontsize=16)
plt.show()

# %% [markdown]
# ### By Seeing the Above Graph we can say that
# #### - Accidents by Aeroflot was in Peak during 1968 -1980
# #### - From 1995 onwards the accidents has been minimised and by thus making it has one of the Safer Airline to travel with

# %% [markdown]
# ## Summary :
#
# ### Detailed analyses of following factors:
#
#    ####  -The planes crashed per year.
#
#    ####  -People aboard per year during crashes.
#
#    ####   -People dead per year during crashes.
#
#    ####    -People survived per year during crashes.
